# %% [markdown]
# # SELENIUM AND PYAUTOGUI

# %% [raw]
# PYAUTOGUI...deskboard automation
# pyauto...Python...automation..graphical user interphase

# %%
import pyautogui as pg   #or pag short name

# %%
pg.position()       #returns the location of mouse pointer
# Out:
# Point(x=582, y=771)

# %%
pg.moveTo(1157,18,4)        #4...4 is time lapse in seconds

# %%
pg.position(6000,6000)
# Out:
# Point(x=6000, y=6000)

# %%
pg.moveTo(750,17)

# %%
pg.moveTo(608,22,2)
pg.click()          #to open new tab

# %%
pg.moveTo(855,23)
pg.click()

# %%
pg.position()
# Out:
# Point(x=855, y=23)

# %%
pg.click(1432,209)
pg.write('pyautogui documentation\n',interval=0.25)

# %%
pg.position()
# Out:
# Point(x=1432, y=209)

# %%
#pg.hotkeys()

# %%
pg.size()
# Out:
# Size(width=1920, height=1080)

# %%
pg.position()
#moveTo
# Out:
# Point(x=1432, y=209)

# %%
pg.moveTo(96,1047)
pg.click()

# %%
pg.hotkey('alt','f4')   #to close the tab

# %%
pg.position()
# Out:
# Point(x=96, y=1047)

# %%
pg.moveTo(457,1057)
pg.click()

# %%
pg.position()
# Out:
# Point(x=457, y=1057)

# %%
pg.moveTo(1304,8)
pg.click()

# %%
pg.alert(text='',title='',button='ok')
pg.alert("your code is good",'alert box',button='abc')
# Out:
# 'abc'

# %%
pg.alert(text='i am',title='simba',button='ok')
pg.alert("your code is good",'alert box',button='abc')
# Out:
# 'abc'

# %%
btn=pg.confirm(text='',title='',buttons=['ok','cancel'])
btn
# Out:
# 'ok'

# %%
if btn=='ok':
    print("you selected it")
else:
    print("file will be deleted")
# Out:
# you selected it

# %%
pg.prompt(text='',title='input box',default='')

# %%
n=pg.password(text='type password',title='work',default='')
if n=='123':  #takses as a string so on number it will not show
    print("log in sucessful")
else:
    print("access failed")
# Out:
# access failed

# %% [markdown]
# # BEAUTIFUL SOOP

# %% [raw]
# WEB SCRAPING IN PYTHON
# for getting /assessing the data on any website and save all data in colums

# %%
#To import html

# %%
import urllib
print(dir(urllib))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'error', 'parse', 'request', 'response']

# %%
help(urllib)
# Out:
# Help on package urllib:
#
# NAME
#     urllib
#
# PACKAGE CONTENTS
#     error
#     parse
#     request
#     response
#     robotparser
#
# FILE
#     c:\users\dell\anaconda3\python\lib\urllib\__init__.py

# %% [raw]
# REQUEST
# RESPONSE

# %% [raw]
# get.request

# %%
help(urllib.request)
# Out:
# Help on module urllib.request in urllib:
#
# NAME
#     urllib.request - An extensible library for opening URLs using a variety of protocols
#
# DESCRIPTION
#     The simplest way to use this module is to call the urlopen function,
#     which accepts a string containing a URL or a Request object (described
#     below).  It opens the URL and returns the results as file-like
#     object; the returned object has some extra methods described below.
#
#     The OpenerDirector manages a collection of Handler objects that do
#     all the actual work.  Each Handler implements a particular protocol or
#     option.  The OpenerDirector is a composite object that invokes the
#     Handlers needed to open the requested URL.  For example, the
#     HTTPHandler performs HTTP GET and POST requests and deals with
#     non-error returns.  The HTTPRedirectHandler automatically deals with
#     HTTP 301, 302, 303 and 307 redirect errors, and the HTTPDigestAuthHandler
# ...

# %%
from urllib.request import urlretrieve
url = 'https://archive.ics.uci.edu/ml/datasets/Forest+Fires.csv'
urlretrieve(url,"forset file")
# Out:
# ('forset file', <http.client.HTTPMessage at 0x23ae9a96208>)

# %%
import pandas as pd
df=pd.read(_csv("forest file.csv",sep=''))
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-08eebb74dc31> in <module>
#       1 import pandas as pd
# ----> 2 df=pd.read(_csv("forest file.csv",sep=''))
#       3 df
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
from urllib.request import urlopen,Request
url="https://en.wikipedia.org/wiki/Wikipedia"
request=Request(url)
response=urlopen(request)
html=response.read()
response.close()
print(type(response))
print(html)

# %% [raw]
# SCRAPY...SCRAPPER.....ADVANCE FORM OF BEAUTIFUL SOOP

# %%
from bs4 import BeautifulSoup
import requests 
url="https://www.msn.com/en-xl/asia/pakistan"
r=requests.get(url)
html_doc=r.text
soup=BeautifulSoup(html_doc)
print(soup)

# %%
print(soup.prettify())

# %%
print(soup.title)
print(type(soup.title))

# %%
soup.title.string

# %%
print(soup.get_text())

# %%
#soup.find_all("img")
#soup.find_all('a')

# %% [markdown]
# # SELENIUM

# %%
for controalling web application
testing...
unfriend all friends from fb..taking a dynamic application 
pyautogui...system control

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
.get
.forward

# %%
driver=webdriver.Chrome()
driver.get("h")

# %% [markdown]
# # Pqt5

# %%
desktop based application
py in
pip install pyqt5
pip install  pyqt5-tools
